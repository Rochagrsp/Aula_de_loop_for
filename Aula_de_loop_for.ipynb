# %% [markdown]
# <a href="https://colab.research.google.com/github/Rochagrsp/Aula_de_loop_for/blob/main/Aula_de_loop_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For

# %%
for i in range (10):
  print("teste",i)
# Out:
# teste 0
# teste 1
# teste 2
# teste 3
# teste 4
# teste 5
# teste 6
# teste 7
# teste 8
# teste 9

# %%
frutas= ['maçã','banana','laranja']
for fruta in frutas:
  print(fruta)
# Out:
# maçã
# banana
# laranja

# %%
lista_vendas=[1000,500,800,1500,200,2300]
for item in lista_vendas:
  print(item)
# Out:
# 1000
# 500
# 800
# 1500
# 200
# 2300

# %%
lista_vendas=[1000,500,800,1500,200,2300]
meta=1200
percentual_bonus= 0.1
for venda in lista_vendas:
  if venda >= meta:
    bonus = percentual_bonus * venda
  else:
    bonus = 0
  print(bonus)
# Out:
# 0
# 0
# 0
# 150.0
# 0
# 230.0

# %%
vendas_diarias=[20,30,40,50]
meta=30
dias_acima_da_meta=0
for venda in vendas_diarias:
  if venda>meta:
    dias_acima_da_meta=dias_acima_da_meta+1
    #dias_acima_da_meta +=1 ** atribuição**
print(dias_acima_da_meta)
# Out:
# 2

# %% [markdown]
# Atividade 01

# %%
vendas_funcionarios=[2800,3200,1500,4000,1000,3500]
meta=3000
percentual_bonus=0.05
for venda in vendas_funcionarios:
  if venda >= meta:
    bonus = percentual_bonus * venda
  else:
    bonus= ("R$ 00,00")
  print(bonus)
# Out:
# R$ 00,00
# 160.0
# R$ 00,00
# 200.0
# R$ 00,00
# 175.0

# %% [markdown]
# Atividade 02

# %%
vendas_diarias=[2000,3000,2500,4000,1800,5000,2700]
meta=2500
dias_acima_da_meta=0
for diaria in vendas_diarias:
  if diaria>meta:
    dias_acima_da_meta +=1
print(dias_acima_da_meta)
# Out:
# 4

# %% [markdown]
# Atividade 03

# %%
vendas_vendedores=[1500,2500,1800,3200,4000,1200,2800]
meta=2000
percentual_bonus=0.8
for venda in vendas_vendedores:
  if venda>=meta:
    bonus= meta*percentual_bonus
  else:
    bonus= 0
  print(bonus)
# Out:
# 0
# 1600.0
# 0
# 1600.0
# 1600.0
# 0
# 1600.0

# %% [markdown]
# Atividade 04

# %%
lista_vendas=[1000,500,800,1500,2000,2300]
meta=1200
contador=0
for venda in lista_vendas:
  if venda>=meta:
    contador+=1
print("Quantidade de vendas que atigiram a meta",contador)
# Out:
# Quantidade de vendas que atigiram a meta 3

# %% [markdown]
# Atividade 05

# %%
lista_vendas=[1000,500,800,1500,2000,2300]
meta=1200
percentual_bonus=0.1
bonus_extra=50
for venda in lista_vendas:
  bonus=0
  if venda>=meta:
     bonus= venda*percentual_bonus
     if venda >=2000:
      bonus+=bonus_extra
  print(f"venda: {venda} - bonus: R${bonus}")
# Out:
# venda: 1000 - bonus: R$0
# venda: 500 - bonus: R$0
# venda: 800 - bonus: R$0
# venda: 1500 - bonus: R$150.0
# venda: 2000 - bonus: R$250.0
# venda: 2300 - bonus: R$280.0

# %% [markdown]
# Atividade 06

# %%
lista_vendas= [1000,500,800,1500,2000,2300]
maior_vendas = lista_vendas[0]
for venda in lista_vendas:
  if venda> maior_vendas:
    maior_vendas=venda
print("A maior venda é:",maior_vendas)
# Out:
# A maior venda é: 2300
